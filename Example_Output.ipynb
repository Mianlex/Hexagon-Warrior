# %%
##First Scheme
##Block 1: Research and Major
#R&D Skills, Natural Science: Chemistry, Physics, Material Sciences, etc., Modelling, Engenering,
import numpy as np
import matplotlib.pyplot as plt
from math import pi
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.collections import LineCollection
from matplotlib.colors import Normalize, ListedColormap
import matplotlib.patheffects as path_effects 

# Caregories: Define the data for radar chart 
## Your Skills/Abilities
categories = ['R&D Skills', 'Natural Science\n(Chemistry, Physics, Materials)', 'Simulation', 'Modelling', 'General Engineering', 'Energy Storage &\n Electrochemistry']
## Level/Score of your skills #correlated to the caregories
values = [4.5, 5, 4, 4, 3, 5]
## Number of variables/categories
num_vars = len(categories)
## Compute angle of each category (divide the plot into equal parts)
angles = [n / float(num_vars) * 2 * pi for n in range(num_vars)]
angles += angles[:1]  # Complete the loop
## Add the first value at the end to close the radar chart loop
values += values[:1]
## Set color palette for categories blocks (using Seaborn for better colors)
#palette = sns.color_palette("coolwarm", 10)
palette = sns.color_palette("pastel",10)
markerline_color = "white"
text_color = palette[0]
line_color = palette[0]
fill_color = palette[0]
marker_color = palette[0]


# Level: label of Level in your skills #Refer to the values above
## As a reference: 
level=["Novice","Advanced Beginner","Competent","Proficient","Expert"]
## Color map for each level
levelpalette = sns.color_palette("cubehelix", len(level)*100)
levelpalette.reverse()
## Transparent parameter in color of level blocks #1=solid 0=transparent
alpha=0.9

# Initialize the radar chart
fig, ax = plt.subplots(figsize=(5, 5), subplot_kw=dict(polar=True),dpi=200)

# Draw one axe per variable and add labels
ax.set_theta_offset(pi / 2)  # Rotate the plot to start from the top
ax.set_theta_direction(-1)  # Set the direction of the angles

# Remove circular boundary (this caused both the circle and polygon to appear)
ax.spines['polar'].set_visible(False)
# Hide radial and angular grid lines
ax.xaxis.set_visible(False)  # Hides the angular grid lines and labels
ax.yaxis.set_visible(False)  # Hides the radial grid lines and labels
    

# Step 1: Create polygonal gridlines manually #Zorder=0 
## Plot the polar line toward the angle of polygon
## Gradient set for laser color
## Get the seaborn color palette and convert to a ListedColormap
cmap = ListedColormap(levelpalette)
## radius define as lenth of level
r = np.linspace(0, len(level), 100)
## Normalize the data points
norm = Normalize(vmin=r.min(), vmax=r.max())

for i in angles:
    #### Convert the data to segments for the LineCollection in gradient color
    theta = np.full_like(r, i) 
    points = np.array([theta, r]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = LineCollection(segments, cmap=cmap, norm=norm,zorder=0,
                        linestyle="--", linewidth=1, alpha=alpha)
    lc.set_array(r)  # Map colors to the radius values (r)
    ax.add_collection(lc)
    
##plot the polygon boundaries
for i in range(1, len(level)):
    ax.plot(angles, [i]*len(angles), linestyle='--', color=levelpalette[i*100], linewidth=1.5, zorder=0,alpha=alpha)

##Manually create the polygonal outer boundary in solid
ax.plot(angles, [5]*len(angles), color=levelpalette[-1], zorder=0, linewidth=1.5, alpha=alpha)  # Outermost polygon boundary


# Step 2: Plot data with customized line and fill color
ax.plot(angles, values, linewidth=2.5, linestyle='solid', color=line_color, clip_on=True)

# Step 3: Fill the area under the plot with transparency to prevent solid blocks
ax.fill(angles, values, color=fill_color, alpha=0.3)  # Lowered alpha to fix color block issue

# Step 4: Add small circles with transparent fill at each data point
ax.scatter(angles[:-1], values[:-1], color=marker_color, s=50, edgecolor=markerline_color, linewidths=2, zorder=30, clip_on=True)

# Step 5: Add custom text labels for each category
for i, angle in enumerate(angles[:-1]):
    x = angle # Adjust multiplier to move text further/closer
    y = len(level)+0.65
    angle_deg = -1*np.degrees(angle)
    #print(angle_deg)
    if abs(angle_deg) >= 90 and abs(angle_deg) <= 270:
        rotation = angle_deg+180
    else:
        rotation = angle_deg
    ax.text(x, y, categories[i],  
            horizontalalignment='center', verticalalignment='center', 
            size=11, color="black",
            weight = 'bold',
             rotation=rotation)


# Step 6: Title    
title = plt.title('Major & Research', size=20,weight='bold', color=text_color, pad=20)
# Apply a stroke (outline) effect to the title
title.set_path_effects([path_effects.Stroke(linewidth=1.5, foreground='black'),  # Black outline
                        path_effects.Normal()])  # Normal text rendering inside

# Remove radial labels (ticks) to prevent interference
ax.set_rticks([])

# Show the chart
plt.ylim(0, len(level)+0.5)
plt.show()

# %%
##Second Scheme
##Block 2: Computer Science
#Python, Matlab, JavaScript, Data Science, Machine Learning, Microsoft Office, 
import numpy as np
import matplotlib.pyplot as plt
from math import pi
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.collections import LineCollection
from matplotlib.colors import Normalize, ListedColormap


# Caregories: Define the data for radar chart 
## Your Skills/Abilities
categories = ['Python', 'Matlab', 'Data Science', 'Machine Learning', 'Microsoft Office', 'Java']
## Level/Score of your skills #correlated to the caregories
values = [4, 4, 4, 3, 4, 2]
## Number of variables/categories
num_vars = len(categories)
## Compute angle of each category (divide the plot into equal parts)
angles = [n / float(num_vars) * 2 * pi for n in range(num_vars)]
angles += angles[:1]  # Complete the loop
## Add the first value at the end to close the radar chart loop
values += values[:1]
## Set color palette for categories blocks (using Seaborn for better colors)
#palette = sns.color_palette("coolwarm", 10)
palette = sns.color_palette("pastel",10)
markerline_color = "white"
text_color = palette[3]
line_color = palette[3]
fill_color = palette[3]
marker_color = palette[3]


# Level: label of Level in your skills #Refer to the values above
## As a reference: 
level=["Novice","Advanced Beginner","Competent","Proficient","Expert"]
## Color map for each level
levelpalette = sns.color_palette("cubehelix", len(level)*100)
levelpalette.reverse()
## Transparent parameter in color of level blocks #1=solid 0=transparent
alpha=0.9

# Initialize the radar chart
fig, ax = plt.subplots(figsize=(5, 5), subplot_kw=dict(polar=True),dpi=200)

# Draw one axe per variable and add labels
ax.set_theta_offset(pi / 2)  # Rotate the plot to start from the top
ax.set_theta_direction(-1)  # Set the direction of the angles

# Remove circular boundary (this caused both the circle and polygon to appear)
ax.spines['polar'].set_visible(False)
# Hide radial and angular grid lines
ax.xaxis.set_visible(False)  # Hides the angular grid lines and labels
ax.yaxis.set_visible(False)  # Hides the radial grid lines and labels
    

# Step 1: Create polygonal gridlines manually #Zorder=0 
## Plot the polar line toward the angle of polygon
## Gradient set for laser color
## Get the seaborn color palette and convert to a ListedColormap
cmap = ListedColormap(levelpalette)
## radius define as lenth of level
r = np.linspace(0, len(level), 100)
## Normalize the data points
norm = Normalize(vmin=r.min(), vmax=r.max())

for i in angles:
    #### Convert the data to segments for the LineCollection in gradient color
    theta = np.full_like(r, i) 
    points = np.array([theta, r]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = LineCollection(segments, cmap=cmap, norm=norm,zorder=0,
                        linestyle="--", linewidth=1, alpha=alpha)
    lc.set_array(r)  # Map colors to the radius values (r)
    ax.add_collection(lc)
    
##plot the polygon boundaries
for i in range(1, len(level)):
    ax.plot(angles, [i]*len(angles), linestyle='--', color=levelpalette[i*100], linewidth=1.5, zorder=0,alpha=alpha)

##Manually create the polygonal outer boundary in solid
ax.plot(angles, [5]*len(angles), color=levelpalette[-1], zorder=0, linewidth=1.5, alpha=alpha)  # Outermost polygon boundary


# Step 2: Plot data with customized line and fill color
ax.plot(angles, values, linewidth=2.5, linestyle='solid', color=line_color, clip_on=True)

# Step 3: Fill the area under the plot with transparency to prevent solid blocks
ax.fill(angles, values, color=fill_color, alpha=0.3)  # Lowered alpha to fix color block issue

# Step 4: Add small circles with transparent fill at each data point
ax.scatter(angles[:-1], values[:-1], color=marker_color, s=50, edgecolor=markerline_color, linewidths=2, zorder=30, clip_on=True)

# Step 5: Add custom text labels for each category
for i, angle in enumerate(angles[:-1]):
    x = angle # Adjust multiplier to move text further/closer
    y = len(level)+0.5
    angle_deg = -1*np.degrees(angle)
    #print(angle_deg)
    if abs(angle_deg) >= 90 and abs(angle_deg) <= 270:
        rotation = angle_deg+180
    else:
        rotation = angle_deg
    ax.text(x, y, categories[i],  
            horizontalalignment='center', verticalalignment='center', 
            size=11, 
            color='black',
            weight = 'bold',
             rotation=rotation)
##Add Title     
title = plt.title('Computer Science', size=20,weight='bold', color=text_color, pad=20)
# Apply a stroke (outline) effect to the title
title.set_path_effects([path_effects.Stroke(linewidth=1.5, foreground='black'),  # Black outline
                        path_effects.Normal()])  # Normal text rendering inside

# Remove radial labels (ticks) to prevent interference
ax.set_rticks([])

# Show the chart
plt.ylim(0, len(level)+0.5)
#plt.
plt.show()

# %%
##Thrid Scheme
##Block 3: Language and Commnications
#English, Chinese, Cantonese, Danish, Team Player, Communication
import numpy as np
import matplotlib.pyplot as plt
from math import pi
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.collections import LineCollection
from matplotlib.colors import Normalize, ListedColormap


# Caregories: Define the data for radar chart 
## Your Skills/Abilities
categories = ['English', 'Chinese', 'Cantonese', 'Danish', 'Team Player', 'Communication Skill']
## Level/Score of your skills #correlated to the caregories
values = [4, 5, 5, 1, 4, 4]
## Number of variables/categories
num_vars = len(categories)
## Compute angle of each category (divide the plot into equal parts)
angles = [n / float(num_vars) * 2 * pi for n in range(num_vars)]
angles += angles[:1]  # Complete the loop
## Add the first value at the end to close the radar chart loop
values += values[:1]
## Set color palette for categories blocks (using Seaborn for better colors)
#palette = sns.color_palette("coolwarm", 10)
palette = sns.color_palette("pastel",10)
markerline_color = "white"
text_color = palette[6]
line_color = palette[6]
fill_color = palette[6]
marker_color = palette[6]


# Level: label of Level in your skills #Refer to the values above
## As a reference: 
level=["Novice","Advanced Beginner","Competent","Proficient","Expert"]
## Color map for each level
levelpalette = sns.color_palette("cubehelix", len(level)*100)
levelpalette.reverse()
## Transparent parameter in color of level blocks #1=solid 0=transparent
alpha=0.9

# Initialize the radar chart
fig, ax = plt.subplots(figsize=(5, 5), subplot_kw=dict(polar=True),dpi=200)

# Draw one axe per variable and add labels
ax.set_theta_offset(pi / 2)  # Rotate the plot to start from the top
ax.set_theta_direction(-1)  # Set the direction of the angles

# Remove circular boundary (this caused both the circle and polygon to appear)
ax.spines['polar'].set_visible(False)
# Hide radial and angular grid lines
ax.xaxis.set_visible(False)  # Hides the angular grid lines and labels
ax.yaxis.set_visible(False)  # Hides the radial grid lines and labels
    

# Step 1: Create polygonal gridlines manually #Zorder=0 
## Plot the polar line toward the angle of polygon
## Gradient set for laser color
## Get the seaborn color palette and convert to a ListedColormap
cmap = ListedColormap(levelpalette)
## radius define as lenth of level
r = np.linspace(0, len(level), 100)
## Normalize the data points
norm = Normalize(vmin=r.min(), vmax=r.max())

for i in angles:
    #### Convert the data to segments for the LineCollection in gradient color
    theta = np.full_like(r, i) 
    points = np.array([theta, r]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = LineCollection(segments, cmap=cmap, norm=norm,zorder=0,
                        linestyle="--", linewidth=1, alpha=alpha)
    lc.set_array(r)  # Map colors to the radius values (r)
    ax.add_collection(lc)
    
##plot the polygon boundaries
for i in range(1, len(level)):
    ax.plot(angles, [i]*len(angles), linestyle='--', color=levelpalette[i*100], linewidth=1.5, zorder=0,alpha=alpha)
    #,label=level[i-1])

##Manually create the polygonal outer boundary in solid
ax.plot(angles, [5]*len(angles), color=levelpalette[-1], zorder=0, linewidth=1.5, alpha=alpha)  # Outermost polygon boundary


# Step 2: Plot data with customized line and fill color
ax.plot(angles, values, linewidth=2.5, linestyle='solid', color=line_color, clip_on=True)

# Step 3: Fill the area under the plot with transparency to prevent solid blocks
ax.fill(angles, values, color=fill_color, alpha=0.3)  # Lowered alpha to fix color block issue

# Step 4: Add small circles with transparent fill at each data point
ax.scatter(angles[:-1], values[:-1], color=marker_color, s=50, edgecolor=markerline_color, linewidths=2, zorder=30, clip_on=True)

# Step 5: Add custom text labels for each category
for i, angle in enumerate(angles[:-1]):
    x = angle # Adjust multiplier to move text further/closer
    y = len(level)+0.5
    angle_deg = -1*np.degrees(angle)
    #print(angle_deg)
    if abs(angle_deg) >= 90 and abs(angle_deg) <= 270:
        rotation = angle_deg+180
    else:
        rotation = angle_deg
    ax.text(x, y, categories[i],  
            horizontalalignment='center', verticalalignment='center', 
            size=11, 
            color='black',
            weight='bold',
             rotation=rotation)


##Add Title     
title = plt.title('Language & Communication', size=20,weight='bold', color=text_color, pad=20)
# Apply a stroke (outline) effect to the title
title.set_path_effects([path_effects.Stroke(linewidth=1.5, foreground='black'),  # Black outline
                        path_effects.Normal()])  # Normal text rendering inside

# Step 8: Add a legend
#ax.legend(loc='upper right', bbox_to_anchor=(1.1, 1.1),ncol=5)
# Add a colorbar (optional, it will reflect the gradient along the radius)
#plt.colorbar(lc, ax=ax)

# Remove radial labels (ticks) to prevent interference
ax.set_rticks([])

# Show the chart
plt.ylim(0, len(level)+0.5)
#plt.
#plt.show()
plt.savefig('Example_withoutlable.jpg', bbox_inches='tight')

# %%
##Fourth Scheme
##Blcok 4: Personality & Character
#INTP Thinker *, 
import numpy as np
import matplotlib.pyplot as plt
from math import pi
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.collections import LineCollection
from matplotlib.colors import Normalize, ListedColormap


# Caregories: Define the data for radar chart 
## Your Skills/Abilities
categories = ['INTP Thinker *', 'Creativity', 'Adaptivity', 'Work Independently', 'Troubleshooting', 'Multitasking']
## Level/Score of your skills #correlated to the caregories
values = [5, 4, 5, 4, 4, 3]
## Number of variables/categories
num_vars = len(categories)
## Compute angle of each category (divide the plot into equal parts)
angles = [n / float(num_vars) * 2 * pi for n in range(num_vars)]
angles += angles[:1]  # Complete the loop
## Add the first value at the end to close the radar chart loop
values += values[:1]
## Set color palette for categories blocks (using Seaborn for better colors)
#palette = sns.color_palette("coolwarm", 10)
palette = sns.color_palette("pastel",10)
markerline_color = "white"
text_color = palette[9]
line_color = palette[9]
fill_color = palette[9]
marker_color = palette[9]


# Level: label of Level in your skills #Refer to the values above
## As a reference: 
level=["Novice","Advanced Beginner","Competent","Proficient","Expert"]
## Color map for each level
levelpalette = sns.color_palette("cubehelix", len(level)*100)
levelpalette.reverse()
## Transparent parameter in color of level blocks #1=solid 0=transparent
alpha=0.9

# Initialize the radar chart
fig, ax = plt.subplots(figsize=(5, 5), subplot_kw=dict(polar=True),dpi=200)

# Draw one axe per variable and add labels
ax.set_theta_offset(pi / 2)  # Rotate the plot to start from the top
ax.set_theta_direction(-1)  # Set the direction of the angles

# Remove circular boundary (this caused both the circle and polygon to appear)
ax.spines['polar'].set_visible(False)
# Hide radial and angular grid lines
ax.xaxis.set_visible(False)  # Hides the angular grid lines and labels
ax.yaxis.set_visible(False)  # Hides the radial grid lines and labels
    

# Step 1: Create polygonal gridlines manually #Zorder=0 
## Plot the polar line toward the angle of polygon
## Gradient set for laser color
## Get the seaborn color palette and convert to a ListedColormap
cmap = ListedColormap(levelpalette)
## radius define as lenth of level
r = np.linspace(0, len(level), 100)
## Normalize the data points
norm = Normalize(vmin=r.min(), vmax=r.max())

for i in angles:
    #### Convert the data to segments for the LineCollection in gradient color
    theta = np.full_like(r, i) 
    points = np.array([theta, r]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = LineCollection(segments, cmap=cmap, norm=norm,zorder=0,
                        linestyle="--", linewidth=1, alpha=alpha)
    lc.set_array(r)  # Map colors to the radius values (r)
    ax.add_collection(lc)
    
##plot the polygon boundaries
for i in range(1, len(level)):
    ax.plot(angles, [i]*len(angles), linestyle='--', color=levelpalette[i*100], linewidth=1.5, zorder=0,alpha=alpha)

##Manually create the polygonal outer boundary in solid
ax.plot(angles, [5]*len(angles), color=levelpalette[-1], zorder=0, linewidth=1.5, alpha=alpha)  # Outermost polygon boundary


# Step 2: Plot data with customized line and fill color
ax.plot(angles, values, linewidth=2.5, linestyle='solid', color=line_color, clip_on=True)

# Step 3: Fill the area under the plot with transparency to prevent solid blocks
ax.fill(angles, values, color=fill_color, alpha=0.3)  # Lowered alpha to fix color block issue

# Step 4: Add small circles with transparent fill at each data point
ax.scatter(angles[:-1], values[:-1], color=marker_color, s=50, edgecolor=markerline_color, linewidths=2, zorder=30, clip_on=True)

# Step 5: Add custom text labels for each category
for i, angle in enumerate(angles[:-1]):
    x = angle # Adjust multiplier to move text further/closer
    y = len(level)+0.5
    angle_deg = -1*np.degrees(angle)
    #print(angle_deg)
    if abs(angle_deg) >= 90 and abs(angle_deg) <= 270:
        rotation = angle_deg+180
    else:
        rotation = angle_deg
    ax.text(x, y, categories[i],  
            horizontalalignment='center', verticalalignment='center', 
            size=11, 
            color='black',
            weight = 'bold',
             rotation=rotation)


##Add Title     
title = plt.title('Personality & Character', size=20,weight='bold', color=text_color, pad=20)
# Apply a stroke (outline) effect to the title
title.set_path_effects([path_effects.Stroke(linewidth=1.5, foreground='black'),  # Black outline
                        path_effects.Normal()])  # Normal text rendering inside

# Remove radial labels (ticks) to prevent interference
ax.set_rticks([])

# Show the chart
plt.ylim(0, len(level)+0.5)
#plt.
plt.show()

# %%
##Legend generation

import numpy as np
import matplotlib.pyplot as plt
from math import pi
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.collections import LineCollection
from matplotlib.colors import Normalize, ListedColormap


# Caregories: Define the data for radar chart 
## Your Skills/Abilities
categories = ['English', 'Chinese', 'Cantonese', 'Danish', 'Team Player', 'Communication Skill']
## Level/Score of your skills #correlated to the caregories
values = [4, 5, 5, 1, 4, 4]
## Number of variables/categories
num_vars = len(categories)
## Compute angle of each category (divide the plot into equal parts)
angles = [n / float(num_vars) * 2 * pi for n in range(num_vars)]
angles += angles[:1]  # Complete the loop
## Add the first value at the end to close the radar chart loop
values += values[:1]
## Set color palette for categories blocks (using Seaborn for better colors)
#palette = sns.color_palette("coolwarm", 10)
palette = sns.color_palette("pastel",10)
markerline_color = "white"
text_color = palette[6]
line_color = palette[6]
fill_color = palette[6]
marker_color = palette[6]


# Level: label of Level in your skills #Refer to the values above
## As a reference: 
level=["Level 1:\nNovice","Level 2:\nAdvanced Beginner","Level 3:\nCompetent","Level 4:\nProficient","Level 5:\nExpert"]
## Color map for each level
levelpalette = sns.color_palette("cubehelix", len(level)*100)
levelpalette.reverse()
## Transparent parameter in color of level blocks #1=solid 0=transparent
alpha=0.9

# Initialize the radar chart
fig, ax = plt.subplots(figsize=(5, 5), subplot_kw=dict(polar=True),dpi=200)

# Draw one axe per variable and add labels
ax.set_theta_offset(pi / 2)  # Rotate the plot to start from the top
ax.set_theta_direction(-1)  # Set the direction of the angles

# Remove circular boundary (this caused both the circle and polygon to appear)
ax.spines['polar'].set_visible(False)
# Hide radial and angular grid lines
ax.xaxis.set_visible(False)  # Hides the angular grid lines and labels
ax.yaxis.set_visible(False)  # Hides the radial grid lines and labels
    

# Step 1: Create polygonal gridlines manually #Zorder=0 
## Plot the polar line toward the angle of polygon
## Gradient set for laser color
## Get the seaborn color palette and convert to a ListedColormap
cmap = ListedColormap(levelpalette)
## radius define as lenth of level
r = np.linspace(0, len(level), 100)
## Normalize the data points
norm = Normalize(vmin=r.min(), vmax=r.max())

for i in angles:
    #### Convert the data to segments for the LineCollection in gradient color
    theta = np.full_like(r, i) 
    points = np.array([theta, r]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = LineCollection(segments, cmap=cmap, norm=norm,zorder=0,
                        linestyle="--", linewidth=1, alpha=alpha)
    lc.set_array(r)  # Map colors to the radius values (r)
    ax.add_collection(lc)
    
##plot the polygon boundaries
for i in range(1, len(level)):
    ax.plot(angles, [i]*len(angles), linestyle='--', color=levelpalette[i*100], linewidth=2, zorder=0,alpha=alpha,label=level[i-1])
    #,label=level[i-1])

##Manually create the polygonal outer boundary in solid
ax.plot(angles, [5]*len(angles), color=levelpalette[-1], zorder=0, linewidth=1.5, alpha=alpha, label=level[-1])  # Outermost polygon boundary


# Step 2: Plot data with customized line and fill color
ax.plot(angles, values, linewidth=2.5, linestyle='solid', color=line_color, clip_on=True)

# Step 3: Fill the area under the plot with transparency to prevent solid blocks
ax.fill(angles, values, color=fill_color, alpha=0.3)  # Lowered alpha to fix color block issue

# Step 4: Add small circles with transparent fill at each data point
ax.scatter(angles[:-1], values[:-1], color=marker_color, s=50, edgecolor=markerline_color, linewidths=2, zorder=30, clip_on=True)

# Step 5: Add custom text labels for each category
for i, angle in enumerate(angles[:-1]):
    x = angle # Adjust multiplier to move text further/closer
    y = len(level)+0.5
    angle_deg = -1*np.degrees(angle)
    #print(angle_deg)
    if abs(angle_deg) >= 90 and abs(angle_deg) <= 270:
        rotation = angle_deg+180
    else:
        rotation = angle_deg
    ax.text(x, y, categories[i],  
            horizontalalignment='center', verticalalignment='center', 
            size=11, 
            color='black',
            weight='bold',
             rotation=rotation)


##Add Title     
title = plt.title('Language & Communication', size=20,weight='bold', color=text_color, pad=20)
# Apply a stroke (outline) effect to the title
title.set_path_effects([path_effects.Stroke(linewidth=1.5, foreground='black'),  # Black outline
                        path_effects.Normal()])  # Normal text rendering inside

# Step 8: Add a legend
ax.legend(bbox_to_anchor=(1.5, 1.3),ncol=5,frameon=False, prop={'weight': 'bold'})
# Add a colorbar (optional, it will reflect the gradient along the radius)
#plt.colorbar(lc, ax=ax)

# Remove radial labels (ticks) to prevent interference
ax.set_rticks([])

# Show the chart
plt.ylim(0, len(level)+0.5)
#plt.
#plt.show()
plt.savefig('Example_withlable.jpg', bbox_inches='tight')
